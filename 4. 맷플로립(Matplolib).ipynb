# %% [markdown]
# ## 맷플로립(matplotlib)
#     - 파이썬의 자료(DataFrame, Series 등..)을 차트(chart)나 플롯(plot)으로 시각화(visualization)하는 모듈
#     - Matplotlib은 다음과 같은 정형화된 차트나 플롯 이외에도 저수준 api를 사용한 다양한 시각화 기능을 제공한다
#     - 라인 플롯(line plot)
#     - 스캐터 플롯(scatter plot)
#     - 컨투어 플롯(contour plot)
#     - 서피스 플롯(surface plot)
#     - 바 차트(bar chart)
#     - 히스토그램(histogram)
#     - 박스 플롯(box plot)✨
#     - 맷플로립은 라이브러리이다.
#
# [맷플로립 공식문서](https://matplotlib.org)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Line plot(라인 플롯)
# - 가장 간단한 플롯
# - 선을 그리고 데이터가 시간, 순서 등에 따라 어떻게 변화되는지 보여주는 용도로 사용한다

# %%
arr = np.array([10, 30, 14, 55])

plt.plot(arr)

plt.show()

# %%
arr = np.array([
    [10, 20, 30, 40],
    [20, 50, 33, 15],
    [17, 5, 2, 0]
])
plt.plot(arr)
plt.show()

# %%
# # 윈도우 맑은 고딕 설정
# plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# 맥 애플고딕 설정
plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# %%
arr = np.array([
    [10, 20, 30, 40],
    [20, 50, 33, 15],
    [17, 5, 2, 0]
])

plt.figure(figsize=(10, 5))

for i, value in enumerate(arr):
    plt.subplot(111)
    plt.plot(arr[i])

plt.grid(True)
plt.title("라인 그래프 ")
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = x ** 3

plt.figure(figsize=(8,4))
plt.plot(x, y)
plt.show()
# 비선형 그래프

# %%
test_df = pd.DataFrame(
    np.random.randn(10, 4).cumsum(axis=0),
    columns=["월", "화", "수", "목"],
    index=np.arange(0, 100, 10)
)

test_df
# Out:
#            월         화         수         목
# 0  -1.622767 -0.265733 -0.213159 -0.203009
# 10 -3.288159  0.155910 -0.396052 -0.162037
# 20 -2.040921  0.408759 -0.330211 -2.087390
# 30 -1.245065  0.282627 -2.313199 -2.746038
# 40 -1.984744  1.387801 -1.947969  0.091041
# 50 -4.307937  2.911021 -1.004217  1.062051
# 60 -4.825449  2.584668 -1.216367  1.386342
# 70 -4.931511  2.315645 -3.447799  0.988559
# 80 -5.443691  1.713592 -5.227488 -0.511157
# 90 -6.222605  1.023663 -4.318406 -0.106158

# %%
plt.figure(figsize=(10, 5))
plt.plot(test_df)
# x축의 제목
plt.xlabel("X축")
# y축의 제목
plt.ylabel("y축")
# 범례
plt.legend(test_df.columns)
plt.show()

# %% [markdown]
# ## bar plot

# %%
np.random.seed(2002)
y = np.random.randint(100, size=10)
y
# Out:
# array([81, 18,  8, 73, 44, 56, 13, 87,  4, 25])

# %%
chr(97)
# Out:
# 'a'

# %%
x = [chr(i) for i in range(97 , 107)]
x
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
# plt.bar(x=x, height=y)
plt.bar(x, y)
# Out:
# <BarContainer object of 10 artists>

# %%
# Series의 값 넣기 
s1 = pd.Series(data=y, index=x)
s1.plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# ## 히스토그램(histogram)
# - 도수 분포표를 그리는 플롯
# - 가로축(계급), 세로축(도수)으로 나타내는 그래프이다

# %%
# 표준 편차
plt.hist(np.random.normal(0, 1, size=1000))
plt.show()

# %% [markdown]
# ## 산포그래프(Scatter)
# - 산점도 서로 다른 두 개의 독립 변수에 대해 두 변수가 얼마나 상관관계를 가지는지 살펴보기 위헤 그리는 그래프이다

# %%
# normal (평균, 표준편차, 개수 )
x1 = np.random.normal(0, 1, size=1000)
x2 = np.random.normal(5, 1, size=1000)
y = np.random.normal(0, 2, size=1000)

# %%
plt.figure(figsize=(8, 4))
plt.scatter(x1, y)
plt.scatter(x2, y)
plt.show()

# %% [markdown]
# ## subplot

# %%
fig = plt.figure()                            # 지저분하거 지우기
# fig = plt.figure(figsize=(8, 4))

fig = plt.figure(figsize=(8, 4), clear=True)   # 지저분하거 지우기

# %%
# 박스를 반으로 2번자름

# 가로 2개, 세로 2개로 나누고 첫 번째 플롯
ax1 = fig.add_subplot(2, 2, 1)
# 가로 2개, 세로 2개로 나누고 두 번째 플롯
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

# %%
fig

# %%
ax1.hist(x1)
ax2.plot(x2)
ax3.scatter(x1, y)

y1 = np.random.randint(100, size=10)
y1
ax4.bar(x, y1)

# ax1.set_xticks([])
# ax1.set_yticks([])

fig

# %%
arr = np.array([10, 30, 14, 55])

# plt.plot(arr, color="g")                -> 컬러
                    # r, g,  pink, puple, 
# plt.plot(arr, color="pink", marker="*")  -> "*" 찍기
plt.plot(arr, color="pink", marker="*", linestyle="-.")   # -> 점선

plt.show()

# %%
plt.plot?
# 꾸미는 코드
# Out:
# Signature:
# plt.plot(
#     *args: 'float | ArrayLike | str',
#     scalex: 'bool' = True,
#     scaley: 'bool' = True,
#     data: 'DataParamType' = None,
#     **kwargs,
# ) -> 'list[Line2D]'
# Docstring:
# Plot y versus x as lines and/or markers.
#
# Call signatures::
#
#     plot([x], y, [fmt], *, data=None, **kwargs)
#     plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
# The coordinates of the points or line nodes are given by *x*, *y*.
#
# The optional parameter *fmt* is a convenient way for defining basic
# formatting like color, marker and linestyle. It's a shortcut string
# notation described in the *Notes* section below.
#
# >>> plot(x, y)        # plot x and y using default line style and color
# >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
# >>> plot(y)           # plot y using x as index array 0..N-1
# >>> plot(y, 'r+')     # ditto, but with red plusses
#
# You can use `.Line2D` properties as keyword arguments for more
# ...
